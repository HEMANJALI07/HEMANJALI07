# %%
print("WELCOME! TO YOUR QUIZ CHATBOT!")
print("Answer the questions by typing a, b, c or d\n")

score = 0

questions = [
    {
        "question": "1. Who is known as the Father of the Indian Constitution?",
        "a": "Mahatma Gandhi",
        "b": "B.R. Ambedkar",
        "c": "Jawaharlal Nehru",
        "d": "Sardar Patel",
        "answer": "b"
    },
    {
        "question": "2. What is the capital city of Australia?",
        "a": "Sydney",
        "b": "Melbourne",
        "c": "Canberra",
        "d": "Perth",
        "answer": "c"
    },
    {
        "question": "3. Who discovered the law of gravity?",
        "a": "Albert Einstein",
        "b": "Galileo Galilei",
        "c": "Isaac Newton",
        "d": "James Watt",
        "answer": "c"
    },
    {
        "question": "4. What is the longest river in the world?",
        "a": "Nile",
        "b": "Amazon",
        "c": "Yangtze",
        "d": "Mississippi",
        "answer": "a"
    },
    {
        "question": "5. In which year did World War II end?",
        "a": "1939",
        "b": "1940",
        "c": "1945",
        "d": "1950",
        "answer": "c"
    },
    {
        "question": "6. Which Indian city is known as the Pink City?",
        "a": "Jaipur",
        "b": "Jodhpur",
        "c": "Udaipur",
        "d": "Bhopal",
        "answer": "a"
    },
    {
        "question": "7. Who painted 'Starry Night'?",
        "a": "Pablo Picasso",
        "b": "Vincent van Gogh",
        "c": "Leonardo da Vinci",
        "d": "Claude Monet",
        "answer": "b"
    },
    {
        "question": "8. Which element has atomic number 1?",
        "a": "Oxygen",
        "b": "Helium",
        "c": "Hydrogen",
        "d": "Nitrogen",
        "answer": "c"
    },
    {
        "question": "9. What is the national currency of Japan?",
        "a": "Yen",
        "b": "Won",
        "c": "Yuan",
        "d": "Ringgit",
        "answer": "a"
    },
    {
        "question": "10. What is the smallest continent in the world?",
        "a": "Europe",
        "b": "Antarctica",
        "c": "Australia",
        "d": "South America",
        "answer": "c"
    }
]

for q in questions:
    print(q["question"])
    print("a)", q["a"])
    print("b)", q["b"])
    print("c)", q["c"])
    print("d)", q["d"])
    
    user_ans = input("Your answer: ").lower()
    
    if user_ans == q["answer"]:
        print("Correct!\n")
        score += 1
    else:
        print("Wrong! Correct answer is:", q["answer"], "\n")

print("Your final score:", score, "/", len(questions))
# Out:
# WELCOME! TO YOUR QUIZ CHATBOT!
# Answer the questions by typing a, b, c or d
#
# 1. Who is known as the Father of the Indian Constitution?
# a) Mahatma Gandhi
# b) B.R. Ambedkar
# c) Jawaharlal Nehru
# d) Sardar Patel
# Your answer:  a
# Wrong! Correct answer is: b
#
# 2. What is the capital city of Australia?
# a) Sydney
# b) Melbourne
# c) Canberra
# d) Perth
